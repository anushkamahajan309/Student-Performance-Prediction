# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/Student_Data.csv")
df.head()
# Out:
#    Study_Hours  Attendance  Assignments_Completed  Previous_Score  Final_Score
# 0          4.4          71                      2              48         70.9
# 1          9.6          63                      9              78        100.0
# 2          7.6          87                      4              70         96.7
# 3          6.4          74                      3              71         92.3
# 4          2.4          67                      2              80         82.7

# %%
df.shape
# Out:
# (500, 5)

# %%
df.columns
# Out:
# Index(['Study_Hours', 'Attendance', 'Assignments_Completed', 'Previous_Score',
#        'Final_Score'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Study_Hours            500 non-null    float64
#  1   Attendance             500 non-null    int64
#  2   Assignments_Completed  500 non-null    int64
#  3   Previous_Score         500 non-null    int64
#  4   Final_Score            500 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 19.7 KB

# %%
df.describe()
# Out:
#        Study_Hours  Attendance  Assignments_Completed  Previous_Score  \
# count   500.000000  500.000000             500.000000      500.000000
# mean      5.488600   76.842000               5.922000       67.728000
# std       2.690369   13.200513               2.662723       16.406962
# min       1.000000   55.000000               2.000000       40.000000
# 25%       3.200000   65.000000               3.000000       53.000000
# 50%       5.600000   77.000000               6.000000       67.500000
# 75%       7.800000   88.000000               8.000000       83.000000
# max       9.900000  100.000000              10.000000       95.000000
#
#        Final_Score
# count   500.000000
# mean     91.585600
# std       8.505627
# min      64.100000
# 25%      86.275000
# 50%      93.400000
# 75%     100.000000
# max     100.000000

# %%
df.isnull().sum()
# Out:
# Study_Hours              0
# Attendance               0
# Assignments_Completed    0
# Previous_Score           0
# Final_Score              0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.isna().any()
# Out:
# Study_Hours              False
# Attendance               False
# Assignments_Completed    False
# Previous_Score           False
# Final_Score              False
# dtype: bool

# %%
df.dtypes
# Out:
# Study_Hours              float64
# Attendance                 int64
# Assignments_Completed      int64
# Previous_Score             int64
# Final_Score              float64
# dtype: object

# %%
X = df.drop("Final_Score", axis=1)
y = df["Final_Score"]

# %%
X.head()
# Out:
#    Study_Hours  Attendance  Assignments_Completed  Previous_Score
# 0          4.4          71                      2              48
# 1          9.6          63                      9              78
# 2          7.6          87                      4              70
# 3          6.4          74                      3              71
# 4          2.4          67                      2              80

# %%
y.head()
# Out:
# 0     70.9
# 1    100.0
# 2     96.7
# 3     92.3
# 4     82.7
# Name: Final_Score, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=56)

# %%
x_train.head()
# Out:
#      Study_Hours  Attendance  Assignments_Completed  Previous_Score
# 47           5.7          64                      6              83
# 252          8.7          92                      5              94
# 172          5.6          78                      4              67
# 383          8.9          90                      7              92
# 163          5.8          62                     10              40

# %%
x_train.shape
# Out:
# (400, 4)

# %%
y_train.shape
# Out:
# (400,)

# %%
x_test.shape
# Out:
# (100, 4)

# %%
y_test.shape
# Out:
# (100,)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.785490342005075

# %%
y_pred = model.predict(x_test)
y_pred[:10]
# Out:
# array([ 96.39669176,  79.08097093,  91.40399145,  85.64736803,
#         86.28607114, 108.13656331,  99.54383779,  89.32270014,
#        106.80011582,  93.86968538])

# %%
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 2.755840351743075

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 12.327234238342049

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.785490342005075

# %%
comparison = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})
comparison.head(10)
# Out:
#    Actual   Predicted
# 0   100.0   96.396692
# 1    78.6   79.080971
# 2    92.4   91.403991
# 3    88.0   85.647368
# 4    89.3   86.286071
# 5   100.0  108.136563
# 6   100.0   99.543838
# 7    91.3   89.322700
# 8   100.0  106.800116
# 9    93.7   93.869685

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Final Score")
plt.ylabel("Predicted Final Score")
plt.title("Actual vs Predicted Final Scores")
plt.show()

# %%
import joblib

# %%
joblib.dump(model,"student_model.pkl")
# Out:
# ['student_model.pkl']
